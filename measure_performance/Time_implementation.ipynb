# %%
# import libraries
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

# New!
import time


import matplotlib.pyplot as plt
from IPython import display
display.set_matplotlib_formats('svg')

# %%
# import dataset (comes with colab!)
data = np.loadtxt(open('sample_data/mnist_train_small.csv','rb'),delimiter=',')

# extract labels (number IDs) and remove from data
labels = data[:,0]
data   = data[:,1:]

# normalize the data to a range of [0 1]
dataNorm = data / np.max(data)

# %%
# Step 1: convert to tensor
dataT   = torch.tensor( dataNorm ).float()
labelsT = torch.tensor( labels ).long()

# Step 2: use scikitlearn to split the data
train_data,test_data, train_labels,test_labels = train_test_split(dataT, labelsT, test_size=.1)


# Step 3: convert into PyTorch Datasets
train_data = torch.utils.data.TensorDataset(train_data,train_labels)
test_data  = torch.utils.data.TensorDataset(test_data,test_labels)

# Step 4: translate into dataloader objects
batchsize  = 32
train_loader = DataLoader(train_data,batch_size=batchsize,shuffle=True,drop_last=True)
test_loader  = DataLoader(test_data,batch_size=test_data.tensors[0].shape[0])

# %%
# create a class for the model
def createTheMNISTNet():

  class mnistNet(nn.Module):
    def __init__(self):
      super().__init__()

      ### input layer
      self.input = nn.Linear(784,64)
      
      ### hidden layer
      self.fc1 = nn.Linear(64,32)
      self.fc2 = nn.Linear(32,32)

      ### output layer
      self.output = nn.Linear(32,10)

    # forward pass
    def forward(self,x):
      x = F.relu( self.input(x) )
      x = F.relu( self.fc1(x) )
      x = F.relu( self.fc2(x) )
      return self.output(x)
  
  # create the model instance
  net = mnistNet()
  
  # loss function
  lossfun = nn.CrossEntropyLoss()

  # optimizer
  optimizer = torch.optim.Adam(net.parameters(),lr=.01)

  return net,lossfun,optimizer

# %%
def funtion2trainTheModel():

  # Start the timer!
  timerInFunction = time.process_time()

  # number of epochs
  numepochs = 10
  
  # create a new model
  net,lossfun,optimizer = createTheMNISTNet()

  # initialize losses
  losses    = torch.zeros(numepochs)
  trainAcc  = []
  testAcc   = []


  # loop over epochs
  for epochi in range(numepochs):

    # loop over training data batches
    batchAcc  = []
    batchLoss = []
    for X,y in train_loader:

      # forward pass and loss
      yHat = net(X)
      loss = lossfun(yHat,y)

      # backprop
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      # loss from this batch
      batchLoss.append(loss.item())

      # compute accuracy
      matches = torch.argmax(yHat,axis=1) == y     # booleans (false/true)
      matchesNumeric = matches.float()             # convert to numbers (0/1)
      accuracyPct = 100*torch.mean(matchesNumeric) # average and x100
      batchAcc.append( accuracyPct )               # add to list of accuracies
    # end of batch loop...

    # now that we've trained through the batches, get their average training accuracy
    trainAcc.append( np.mean(batchAcc) )

    # and get average losses across the batches
    losses[epochi] = np.mean(batchLoss)

    # test accuracy
    X,y = next(iter(test_loader)) # extract X,y from test dataloader
    with torch.no_grad(): # deactivates autograd
      yHat = net(X)
      
    # compare the following really long line of code to the training accuracy lines
    testAcc.append( 100*torch.mean((torch.argmax(yHat,axis=1)==y).float()) )

    # Finally, report the epoch number, computation time, and accuracy
    comptime = time.process_time() - timerInFunction
    print(f'Epoch {epochi+1}/{numepochs}, elapsed time: {comptime:.2f} sec, test accuracy {testAcc[-1]:.0f}%')

  # end epochs

  # function output
  return trainAcc,testAcc,losses,net

# %%
trainAcc,testAcc,losses,net = funtion2trainTheModel()
# Out:
# Epoch 1/10, elapsed time: 1.20 sec, test accuracy 93%
# Epoch 2/10, elapsed time: 2.45 sec, test accuracy 93%
# Epoch 3/10, elapsed time: 3.78 sec, test accuracy 93%
# Epoch 4/10, elapsed time: 5.05 sec, test accuracy 96%
# Epoch 5/10, elapsed time: 6.33 sec, test accuracy 95%
# Epoch 6/10, elapsed time: 7.64 sec, test accuracy 96%
# Epoch 7/10, elapsed time: 8.94 sec, test accuracy 96%
# Epoch 8/10, elapsed time: 10.27 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.60 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.90 sec, test accuracy 95%

# %%
# now run a second timer over repeated iterations

# Start the timer! (note the different variable name)
timerOutsideFunction = time.process_time()

for i in range(10):
  funtion2trainTheModel()

TotalExperimentTime = time.process_time() - timerOutsideFunction
print(f'\n\n\nTotal elapsed experiment time: {TotalExperimentTime/60:.2f} minutes')
# Out:
# Epoch 1/10, elapsed time: 1.11 sec, test accuracy 92%
# Epoch 2/10, elapsed time: 2.34 sec, test accuracy 92%
# Epoch 3/10, elapsed time: 3.61 sec, test accuracy 94%
# Epoch 4/10, elapsed time: 4.92 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.22 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.59 sec, test accuracy 95%
# Epoch 7/10, elapsed time: 8.89 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 10.18 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.47 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.78 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.10 sec, test accuracy 93%
# Epoch 2/10, elapsed time: 2.36 sec, test accuracy 93%
# Epoch 3/10, elapsed time: 3.64 sec, test accuracy 94%
# Epoch 4/10, elapsed time: 4.92 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.26 sec, test accuracy 95%
# Epoch 6/10, elapsed time: 7.56 sec, test accuracy 94%
# Epoch 7/10, elapsed time: 8.86 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 10.16 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.46 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.73 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.12 sec, test accuracy 91%
# Epoch 2/10, elapsed time: 2.38 sec, test accuracy 94%
# Epoch 3/10, elapsed time: 3.67 sec, test accuracy 95%
# Epoch 4/10, elapsed time: 4.96 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.23 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.49 sec, test accuracy 94%
# Epoch 7/10, elapsed time: 8.82 sec, test accuracy 94%
# Epoch 8/10, elapsed time: 10.11 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.40 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.68 sec, test accuracy 94%
# Epoch 1/10, elapsed time: 1.13 sec, test accuracy 91%
# Epoch 2/10, elapsed time: 2.37 sec, test accuracy 92%
# Epoch 3/10, elapsed time: 3.64 sec, test accuracy 94%
# Epoch 4/10, elapsed time: 4.93 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.22 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.51 sec, test accuracy 95%
# Epoch 7/10, elapsed time: 8.82 sec, test accuracy 96%
# Epoch 8/10, elapsed time: 10.11 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.41 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.70 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.12 sec, test accuracy 93%
# Epoch 2/10, elapsed time: 2.32 sec, test accuracy 92%
# Epoch 3/10, elapsed time: 3.61 sec, test accuracy 94%
# Epoch 4/10, elapsed time: 4.86 sec, test accuracy 95%
# Epoch 5/10, elapsed time: 6.14 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.41 sec, test accuracy 94%
# Epoch 7/10, elapsed time: 8.72 sec, test accuracy 94%
# Epoch 8/10, elapsed time: 9.99 sec, test accuracy 94%
# Epoch 9/10, elapsed time: 11.29 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.57 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.04 sec, test accuracy 93%
# Epoch 2/10, elapsed time: 2.21 sec, test accuracy 94%
# Epoch 3/10, elapsed time: 3.46 sec, test accuracy 93%
# Epoch 4/10, elapsed time: 4.73 sec, test accuracy 95%
# Epoch 5/10, elapsed time: 6.01 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.27 sec, test accuracy 95%
# Epoch 7/10, elapsed time: 8.54 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 9.81 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.07 sec, test accuracy 96%
# Epoch 10/10, elapsed time: 12.33 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.09 sec, test accuracy 90%
# Epoch 2/10, elapsed time: 2.34 sec, test accuracy 93%
# Epoch 3/10, elapsed time: 3.65 sec, test accuracy 95%
# Epoch 4/10, elapsed time: 4.95 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.23 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.47 sec, test accuracy 94%
# Epoch 7/10, elapsed time: 8.76 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 10.02 sec, test accuracy 94%
# Epoch 9/10, elapsed time: 11.31 sec, test accuracy 94%
# Epoch 10/10, elapsed time: 12.64 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.11 sec, test accuracy 92%
# Epoch 2/10, elapsed time: 2.37 sec, test accuracy 93%
# Epoch 3/10, elapsed time: 3.65 sec, test accuracy 94%
# Epoch 4/10, elapsed time: 4.95 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.26 sec, test accuracy 93%
# Epoch 6/10, elapsed time: 7.54 sec, test accuracy 95%
# Epoch 7/10, elapsed time: 8.80 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 10.07 sec, test accuracy 94%
# Epoch 9/10, elapsed time: 11.35 sec, test accuracy 94%
# Epoch 10/10, elapsed time: 12.66 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.09 sec, test accuracy 92%
# Epoch 2/10, elapsed time: 2.27 sec, test accuracy 94%
# Epoch 3/10, elapsed time: 3.48 sec, test accuracy 95%
# Epoch 4/10, elapsed time: 4.72 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 5.98 sec, test accuracy 93%
# Epoch 6/10, elapsed time: 7.23 sec, test accuracy 94%
# Epoch 7/10, elapsed time: 8.49 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 9.74 sec, test accuracy 93%
# Epoch 9/10, elapsed time: 11.05 sec, test accuracy 96%
# Epoch 10/10, elapsed time: 12.34 sec, test accuracy 95%
# Epoch 1/10, elapsed time: 1.10 sec, test accuracy 94%
# Epoch 2/10, elapsed time: 2.32 sec, test accuracy 94%
# Epoch 3/10, elapsed time: 3.57 sec, test accuracy 94%
# Epoch 4/10, elapsed time: 4.87 sec, test accuracy 94%
# Epoch 5/10, elapsed time: 6.16 sec, test accuracy 94%
# Epoch 6/10, elapsed time: 7.39 sec, test accuracy 95%
# Epoch 7/10, elapsed time: 8.66 sec, test accuracy 95%
# Epoch 8/10, elapsed time: 9.96 sec, test accuracy 95%
# Epoch 9/10, elapsed time: 11.23 sec, test accuracy 95%
# Epoch 10/10, elapsed time: 12.55 sec, test accuracy 95%
#
#
#
# Total elapsed experiment time: 2.10 minutes
